# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
url='https://www.webscraper.io/test-sites/e-commerce/allinone/computers/tablets'

# %%
r=requests.get(url)

# %%
r

# %%
soup=bs(r.text,"lxml")

# %%
soup

# %%
soup.div

# %%
soup.div.div

# %%
boxes=soup.find_all('div',class_="col-md-4 col-xl-4 col-lg-4")
print(boxes)

# %%
len(boxes)

# %%
box=soup.find_all("div",class_='col-md-4 col-xl-4 col-lg-4')[3]

# %%
box

# %%
price=box.find("h4",class_="float-end price card-title pull-right")
print(price.text)

# %%
des=box.find("p",class_="description card-text")
des.text

# %%
nav=soup.find_all('ul',class_="nav flex-column",id="side-menu")
nav

# %%
c=soup.find_all("li",class_="nav-item ")
c

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
url1="https://ticker.finology.in/"
r=requests.get(url1)
print(r)
# Out:
# <Response [200]>

# %%
soup=bs(r.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-136614031-6"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#
#         gtag('config', 'UA-136614031-6');
#     </script>
# <!-- Required meta tags -->
# <title>
# 	Fundamental Stock Analysis: Balance Sheet, Ratio analysis &amp; financial tools
# </title><meta content="https://ticker.finology.in/" property="og:site_name"/>
# <meta content="Fundamental Stock Analysis: Balance Sheet, Ratio analysis &amp; financial tools" property="og:title"/>
# <meta content="Unlock the Power of Fundamental Stock Analysis: Financial Statements, Balance Sheet, Reports, and Ratios. Free forever." property="og:description"/>
# ...

# %%
soup.table
# Out:
# <table class="table table-sm table-hover screenertable">
# <thead>
# <tr>
# <th scope="col">Company</th>
# <th scope="col">Price<span class="muted">Rs.</span></th>
# <th scope="col">Day High<span class="muted">Rs.</span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <a class="complink" href="company/IOC">Indian Oil Corp.</a>
# </td>
# <td class="Number">103.45</td>
# <td class="Number">106.90</td>
# </tr>
# <tr>
# <td>
# <a class="complink" href="company/TRENT">Trent</a>
# </td>
# <td class="Number">2452.85</td>
# <td class="Number">2503.85</td>
# </tr>
# <tr>
# <td>
# <a class="complink" href="company/ALKEM">Alkem Laboratories</a>
# </td>
# <td class="Number">4232.70</td>
# <td class="Number">4300.00</td>
# </tr>
# <tr>
# <td>
# <a class="complink" href="company/BSE">BSE</a>
# </td>
# <td class="Number">2070.70</td>
# <td class="Number">2084.40</td>
# </tr>
# <tr>
# <td>
# <a class="complink" href="company/INDUSINDBK">Indusind Bank</a>
# </td>
# <td class="Number">1488.95</td>
# ...

# %%
tables=soup.find("table",class_="table table-sm table-hover screenertable")
print(tables.text)
# Out:
# Company
# PriceRs.
# Day HighRs.
#
#
#
#
#
# Indian Oil Corp.
#
# 103.45
# 106.90
#
#
#
# Trent
#
# 2452.85
# 2503.85
#
#
#
# Alkem Laboratories
#
# 4232.70
# 4300.00
#
#
#
# BSE
#
# 2070.70
# 2084.40
#
#
#
# Indusind Bank
#
# 1488.95
# 1495.95
#
#
#
# Suzlon Energy
#
# 37.40
# 39.20
#
#
#
# Aurobindo Pharma
#
# 936.55
# 947.70
#
#
#
# JP Power Ventures
#
# 13.85
# 14.65
#
#
#
# JSW Infrastructure
#
# 202.35
# 215.45
#
#
#
# Central Dep. Service
#
# 1608.60
# 1630.00
#
#
#
# Neyveli Lignite
#
# 151.80
# 154.00
#
#
#
# Railtel Corporation Of India Ltd.
#
# 248.35
# 258.30
#
#
#
# Dilip Buildcon
#
# 357.15
# 365.30
#
#
#
# JK Tyres & Inds.
#
# 355.15
# 363.40
#
#
#
# Varun Beverages
#
# 1008.85
# 1024.00

# %%
headers=tables.find_all("th")

# %%
headers
# Out:
# [<th scope="col">Company</th>,
#  <th scope="col">Price<span class="muted">Rs.</span></th>,
#  <th scope="col">Day High<span class="muted">Rs.</span></th>]

# %%
title=[]
for i in  headers:
    x=i.text
    title.append(x)

# %%
title
# Out:
# ['Company', 'PriceRs.', 'Day HighRs.']

# %%
df=pd.DataFrame(columns=title)
print(df)
# Out:
# Empty DataFrame
# Columns: [Company, PriceRs., Day HighRs.]
# Index: []

# %%
c1=tables.find_all("a",class_="complink")

# %%
column1=[]
for i in c1:
    x=i.text
    column1.append(x)

# %%
column1
# Out:
# ['Indian Oil Corp.',
#  'Trent',
#  'Alkem Laboratories',
#  'BSE',
#  'Indusind Bank',
#  'Suzlon Energy',
#  'Aurobindo Pharma',
#  'JP Power Ventures',
#  'JSW Infrastructure',
#  'Central Dep. Service',
#  'Neyveli Lignite',
#  'Railtel Corporation Of India Ltd.',
#  'Dilip Buildcon',
#  'JK Tyres & Inds.',
#  'Varun Beverages']

# %%
df1=pd.DataFrame({"ccc":column1})

# %%
df1
# Out:
#                                   ccc
# 0                    Indian Oil Corp.
# 1                               Trent
# 2                  Alkem Laboratories
# 3                                 BSE
# 4                       Indusind Bank
# 5                       Suzlon Energy
# 6                    Aurobindo Pharma
# 7                   JP Power Ventures
# 8                  JSW Infrastructure
# 9                Central Dep. Service
# 10                    Neyveli Lignite
# 11  Railtel Corporation Of India Ltd.
# 12                     Dilip Buildcon
# 13                   JK Tyres & Inds.
# 14                    Varun Beverages

# %%
rows=tables.find_all("tr")
print(rows)
# Out:
# [<tr>
# <th scope="col">Company</th>
# <th scope="col">Price<span class="muted">Rs.</span></th>
# <th scope="col">Day High<span class="muted">Rs.</span></th>
# </tr>, <tr>
# <td>
# <a class="complink" href="company/IOC">Indian Oil Corp.</a>
# </td>
# <td class="Number">103.45</td>
# <td class="Number">106.90</td>
# </tr>, <tr>
# <td>
# <a class="complink" href="company/TRENT">Trent</a>
# </td>
# <td class="Number">2452.85</td>
# <td class="Number">2503.85</td>
# </tr>, <tr>
# <td>
# <a class="complink" href="company/ALKEM">Alkem Laboratories</a>
# </td>
# <td class="Number">4232.70</td>
# <td class="Number">4300.00</td>
# </tr>, <tr>
# <td>
# <a class="complink" href="company/BSE">BSE</a>
# </td>
# <td class="Number">2070.70</td>
# <td class="Number">2084.40</td>
# </tr>, <tr>
# <td>
# <a class="complink" href="company/INDUSINDBK">Indusind Bank</a>
# </td>
# <td class="Number">1488.95</td>
# <td class="Number">1495.95</td>
# </tr>, <tr>
# <td>
# ...

# %%
for i in rows[1:]:
    print(i.text)
# Out:
# Indian Oil Corp.
#
# 103.45
# 106.90
#
#
#
# Trent
#
# 2452.85
# 2503.85
#
#
#
# Alkem Laboratories
#
# 4232.70
# 4300.00
#
#
#
# BSE
#
# 2070.70
# 2084.40
#
#
#
# Indusind Bank
#
# 1488.95
# 1495.95
#
#
#
# Suzlon Energy
#
# 37.40
# 39.20
#
#
#
# Aurobindo Pharma
#
# 936.55
# 947.70
#
#
#
# JP Power Ventures
#
# 13.85
# 14.65
#
#
#
# JSW Infrastructure
#
# 202.35
# 215.45
#
#
#
# Central Dep. Service
#
# 1608.60
# 1630.00
#
#
#
# Neyveli Lignite
#
# 151.80
# 154.00
#
#
#
# Railtel Corporation Of India Ltd.
#
# 248.35
# 258.30
#
#
#
# Dilip Buildcon
#
# 357.15
# 365.30
#
#
#
# JK Tyres & Inds.
#
# 355.15
# 363.40
#
#
#
# Varun Beverages
#
# 1008.85
# 1024.00

# %%
for i in rows[1:]:
    data=i.find_all("td")
    print(data)
# Out:
# [<td>
# <a class="complink" href="company/IOC">Indian Oil Corp.</a>
# </td>, <td class="Number">103.45</td>, <td class="Number">106.90</td>]
# [<td>
# <a class="complink" href="company/TRENT">Trent</a>
# </td>, <td class="Number">2452.85</td>, <td class="Number">2503.85</td>]
# [<td>
# <a class="complink" href="company/ALKEM">Alkem Laboratories</a>
# </td>, <td class="Number">4232.70</td>, <td class="Number">4300.00</td>]
# [<td>
# <a class="complink" href="company/BSE">BSE</a>
# </td>, <td class="Number">2070.70</td>, <td class="Number">2084.40</td>]
# [<td>
# <a class="complink" href="company/INDUSINDBK">Indusind Bank</a>
# </td>, <td class="Number">1488.95</td>, <td class="Number">1495.95</td>]
# [<td>
# <a class="complink" href="company/SUZLON">Suzlon Energy</a>
# </td>, <td class="Number">37.40</td>, <td class="Number">39.20</td>]
# [<td>
# <a class="complink" href="company/AUROPHARMA">Aurobindo Pharma</a>
# </td>, <td class="Number">936.55</td>, <td class="Number">947.70</td>]
# ...

# %%
for i in rows[1:]:
    data=i.find_all("td")
    row=[tr.text for tr in data]
    print(row)
# Out:
# ['\nIndian Oil Corp.\n', '103.45', '106.90']
# ['\nTrent\n', '2452.85', '2503.85']
# ['\nAlkem Laboratories\n', '4232.70', '4300.00']
# ['\nBSE\n', '2070.70', '2084.40']
# ['\nIndusind Bank\n', '1488.95', '1495.95']
# ['\nSuzlon Energy\n', '37.40', '39.20']
# ['\nAurobindo Pharma\n', '936.55', '947.70']
# ['\nJP Power Ventures\n', '13.85', '14.65']
# ['\nJSW Infrastructure\n', '202.35', '215.45']
# ['\nCentral Dep. Service\n', '1608.60', '1630.00']
# ['\nNeyveli Lignite\n', '151.80', '154.00']
# ['\nRailtel Corporation Of India Ltd.\n', '248.35', '258.30']
# ['\nDilip Buildcon\n', '357.15', '365.30']
# ['\nJK Tyres & Inds.\n', '355.15', '363.40']
# ['\nVarun Beverages\n', '1008.85', '1024.00']

# %%
l=len(df)

# %%
for i in rows[1:]:
    data=i.find_all("td")
    row =[tr.text for tr in data]
    print(row)
    l=len(df)
    df.loc[l]=row
# Out:
# ['\nIndian Oil Corp.\n', '103.45', '106.90']
# ['\nTrent\n', '2452.85', '2503.85']
# ['\nAlkem Laboratories\n', '4232.70', '4300.00']
# ['\nBSE\n', '2070.70', '2084.40']
# ['\nIndusind Bank\n', '1488.95', '1495.95']
# ['\nSuzlon Energy\n', '37.40', '39.20']
# ['\nAurobindo Pharma\n', '936.55', '947.70']
# ['\nJP Power Ventures\n', '13.85', '14.65']
# ['\nJSW Infrastructure\n', '202.35', '215.45']
# ['\nCentral Dep. Service\n', '1608.60', '1630.00']
# ['\nNeyveli Lignite\n', '151.80', '154.00']
# ['\nRailtel Corporation Of India Ltd.\n', '248.35', '258.30']
# ['\nDilip Buildcon\n', '357.15', '365.30']
# ['\nJK Tyres & Inds.\n', '355.15', '363.40']
# ['\nVarun Beverages\n', '1008.85', '1024.00']

# %%
print(df)
# Out:
#                                   Company PriceRs. Day HighRs.
# 0                    \nIndian Oil Corp.\n   103.45      106.90
# 1                               \nTrent\n  2452.85     2503.85
# 2                  \nAlkem Laboratories\n  4232.70     4300.00
# 3                                 \nBSE\n  2070.70     2084.40
# 4                       \nIndusind Bank\n  1488.95     1495.95
# 5                       \nSuzlon Energy\n    37.40       39.20
# 6                    \nAurobindo Pharma\n   936.55      947.70
# 7                   \nJP Power Ventures\n    13.85       14.65
# 8                  \nJSW Infrastructure\n   202.35      215.45
# 9                \nCentral Dep. Service\n  1608.60     1630.00
# 10                    \nNeyveli Lignite\n   151.80      154.00
# 11  \nRailtel Corporation Of India Ltd.\n   248.35      258.30
# 12                     \nDilip Buildcon\n   357.15      365.30
# 13                   \nJK Tyres & Inds.\n   355.15      363.40
# ...
