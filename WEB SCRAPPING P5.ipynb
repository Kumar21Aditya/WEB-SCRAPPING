# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs

# %%
PRICE=[]
DESC=[]
NAME=[]
RATING=[]

# %%
for i in range(1,11):
    url="https://www.flipkart.com/search?q=MOBILE+UNDER+10000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(i)
    r=requests.get(url)
    print(r)

    soup=bs(r.text,"lxml")
    box=soup.find_all("div",class_="_1YokD2 _3Mn1Gg")
    Names=soup.find_all("div",class_="_4rR01T")
    for i in Names:
        x=i.text
        NAME.append(x)
    print(len(NAME))    

    Prices=soup.find_all("div",class_="_30jeq3 _1_WHN1")
    for i in Prices:
        y=i.text
        PRICE.append(y)
    print(len(NAME))  
    
    Desc=soup.find_all("ul",class_="_1xgFaf")
    for i in Desc:
        z=i.text
        DESC.append(z)
    print(len(DESC))  
    
    Rating=soup.find_all("span",class_="_2_R_DZ")
    for i in Rating:
        a=i.text
        RATING.append(x)
    print(len(RATING))
# Out:
# <Response [200]>
# 24
# 24
# 24
# 24
# <Response [200]>
# 48
# 48
# 48
# 48
# <Response [200]>
# 72
# 72
# 72
# 72
# <Response [200]>
# 96
# 96
# 96
# 95
# <Response [200]>
# 120
# 120
# 120
# 119
# <Response [200]>
# 144
# 144
# 144
# 142
# <Response [200]>
# 144
# 144
# 144
# 142
# <Response [200]>
# 168
# 168
# 168
# 166
# <Response [200]>
# 192
# 192
# 192
# 190
# <Response [200]>
# 216
# 216
# 216
# 214

# %%
df=pd.DataFrame({"Model_Name":NAME,"Model_Price":PRICE,"Model_desc":DESC})

# %%
df
# Out:
#                                             Model_Name Model_Price  \
# 0            SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)     ₹12,490
# 1                 POCO X5 5G (Supernova Green, 256 GB)     ₹14,999
# 2                        REDMI 12 (Jade Black, 128 GB)      ₹9,299
# 3                       REDMI 12C (Matte Black, 64 GB)      ₹6,799
# 4                       REDMI 12 (Pastel Blue, 128 GB)      ₹9,299
# ..                                                 ...         ...
# 211               Infinix Smart 4 Plus (Violet, 32 GB)      ₹9,999
# 212  Nokia G11 Plus DS 50MP Camera, 8MP+2MP Dual Fr...      ₹9,499
# 213            MOTOROLA G10 Power (Breeze Blue, 64 GB)      ₹9,999
# 214                      SAMSUNG A04 e (Copper, 64 GB)      ₹9,799
# 215                          Nokia C 30 (Green, 32 GB)      ₹9,999
#
#                                             Model_desc
# 0    6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...
# ...
